# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
values = np.zeros(1000)
values[0] = random.uniform(1000,2000)
print(values[0])
for i in range(len(values)-1):
    rand=random.uniform(-0.1,0.105)
    values[i+1]=values[i]*(1+rand)
# Out:
# 1726.738428349271

# %%
plt.plot(values)
plt.show()

# %%
timesteps=2
first_flag=True
import queue
q = queue.Queue(timesteps)
bought_value=[]
tmp=[]


for i,value in enumerate(values):
    q.put(value)
    
    break
